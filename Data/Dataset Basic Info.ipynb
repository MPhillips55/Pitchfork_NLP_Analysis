# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('content.csv')
df.head()
# Out:
#    reviewid                                            content
# 0     22703  “Trip-hop” eventually became a ’90s punchline,...
# 1     22721  Eight years, five albums, and two EPs in, the ...
# 2     22659  Minneapolis’ Uranium Club seem to revel in bei...
# 3     22661  Kleenex began with a crash. It transpired one ...
# 4     22725  It is impossible to consider a given release b...

# %%
df.shape
# Out:
# (18393, 2)

# %%
df1 = pd.read_csv('years.csv')
df1.head()
# Out:
#    reviewid    year
# 0     22703  1998.0
# 1     22721  2016.0
# 2     22659  2016.0
# 3     22661  2016.0
# 4     22725  2016.0

# %%
df1.shape
# Out:
# (19108, 2)

# %%
df2 = pd.read_csv('reviews.csv')
df2.head()
# Out:
#    reviewid                 title            artist  \
# 0     22703             mezzanine    massive attack
# 1     22721          prelapsarian          krallice
# 2     22659  all of them naturals      uranium club
# 3     22661           first songs  kleenex, liliput
# 4     22725             new start              taso
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/22703-mezz...    9.3               0
# 1  http://pitchfork.com/reviews/albums/22721-prel...    7.9               0
# 2  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 3  http://pitchfork.com/reviews/albums/22661-firs...    9.0               1
# 4  http://pitchfork.com/reviews/albums/22725-new-...    8.1               0
#
#            author               author_type    pub_date  pub_weekday  pub_day  \
# 0     nate patrin               contributor  2017-01-08            6        8
# 1        zoe camp               contributor  2017-01-07            5        7
# 2  david glickman               contributor  2017-01-07            5        7
# 3      jenn pelly  associate reviews editor  2017-01-06            4        6
# 4    kevin lozano        tracks coordinator  2017-01-06            4        6
#
#    pub_month  pub_year
# 0          1      2017
# 1          1      2017
# 2          1      2017
# 3          1      2017
# 4          1      2017

# %%
df2.shape
# Out:
# (18393, 13)

# %%
df3 = pd.read_csv('labels.csv')
df3.head()
# Out:
#    reviewid               label
# 0     22703              virgin
# 1     22721           hathenter
# 2     22659        static shock
# 3     22659  fashionable idiots
# 4     22661     kill rock stars

# %%
df3.shape
# Out:
# (20190, 2)

# %%
df4 = pd.read_csv('genres.csv')
df4.head()
# Out:
#    reviewid       genre
# 0     22703  electronic
# 1     22721       metal
# 2     22659        rock
# 3     22661        rock
# 4     22725  electronic

# %%
df4.shape
# Out:
# (22680, 2)

# %%
df5 = pd.read_csv('artists.csv')
df5.head()
# Out:
#    reviewid          artist
# 0     22703  massive attack
# 1     22721        krallice
# 2     22659    uranium club
# 3     22661         kleenex
# 4     22661         liliput

# %%
df5.shape
# Out:
# (18831, 2)

# %%
mdf = pd.merge(left=df2, right=df1, left_on='reviewid', right_on='reviewid')
mdf.head()
# Out:
#    reviewid                 title            artist  \
# 0     22703             mezzanine    massive attack
# 1     22721          prelapsarian          krallice
# 2     22659  all of them naturals      uranium club
# 3     22661           first songs  kleenex, liliput
# 4     22725             new start              taso
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/22703-mezz...    9.3               0
# 1  http://pitchfork.com/reviews/albums/22721-prel...    7.9               0
# 2  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 3  http://pitchfork.com/reviews/albums/22661-firs...    9.0               1
# 4  http://pitchfork.com/reviews/albums/22725-new-...    8.1               0
#
#            author               author_type    pub_date  pub_weekday  pub_day  \
# 0     nate patrin               contributor  2017-01-08            6        8
# 1        zoe camp               contributor  2017-01-07            5        7
# 2  david glickman               contributor  2017-01-07            5        7
# 3      jenn pelly  associate reviews editor  2017-01-06            4        6
# 4    kevin lozano        tracks coordinator  2017-01-06            4        6
#
#    pub_month  pub_year    year
# 0          1      2017  1998.0
# 1          1      2017  2016.0
# 2          1      2017  2016.0
# 3          1      2017  2016.0
# 4          1      2017  2016.0

# %%
mdf2 = pd.merge(left=mdf, right=df4, left_on='reviewid', right_on='reviewid')
mdf2.head()
# Out:
#    reviewid                 title            artist  \
# 0     22703             mezzanine    massive attack
# 1     22721          prelapsarian          krallice
# 2     22659  all of them naturals      uranium club
# 3     22661           first songs  kleenex, liliput
# 4     22725             new start              taso
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/22703-mezz...    9.3               0
# 1  http://pitchfork.com/reviews/albums/22721-prel...    7.9               0
# 2  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 3  http://pitchfork.com/reviews/albums/22661-firs...    9.0               1
# 4  http://pitchfork.com/reviews/albums/22725-new-...    8.1               0
#
#            author               author_type    pub_date  pub_weekday  pub_day  \
# 0     nate patrin               contributor  2017-01-08            6        8
# 1        zoe camp               contributor  2017-01-07            5        7
# 2  david glickman               contributor  2017-01-07            5        7
# 3      jenn pelly  associate reviews editor  2017-01-06            4        6
# 4    kevin lozano        tracks coordinator  2017-01-06            4        6
#
#    pub_month  pub_year    year       genre
# 0          1      2017  1998.0  electronic
# 1          1      2017  2016.0       metal
# 2          1      2017  2016.0        rock
# 3          1      2017  2016.0        rock
# 4          1      2017  2016.0  electronic

# %%
mdf3 = pd.merge(left=mdf2, right=df3, left_on='reviewid', right_on='reviewid')
mdf3.head()
# Out:
#    reviewid                 title            artist  \
# 0     22703             mezzanine    massive attack
# 1     22721          prelapsarian          krallice
# 2     22659  all of them naturals      uranium club
# 3     22659  all of them naturals      uranium club
# 4     22661           first songs  kleenex, liliput
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/22703-mezz...    9.3               0
# 1  http://pitchfork.com/reviews/albums/22721-prel...    7.9               0
# 2  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 3  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 4  http://pitchfork.com/reviews/albums/22661-firs...    9.0               1
#
#            author               author_type    pub_date  pub_weekday  pub_day  \
# 0     nate patrin               contributor  2017-01-08            6        8
# 1        zoe camp               contributor  2017-01-07            5        7
# 2  david glickman               contributor  2017-01-07            5        7
# 3  david glickman               contributor  2017-01-07            5        7
# 4      jenn pelly  associate reviews editor  2017-01-06            4        6
#
#    pub_month  pub_year    year       genre               label
# 0          1      2017  1998.0  electronic              virgin
# 1          1      2017  2016.0       metal           hathenter
# 2          1      2017  2016.0        rock        static shock
# 3          1      2017  2016.0        rock  fashionable idiots
# 4          1      2017  2016.0        rock     kill rock stars

# %%
mdf3.to_csv('merged_review_data.csv')

# %%
df = pd.read_csv('merged_review_data.csv')
col_name = 'Unnamed: 0'
df.drop(col_name, axis=1, inplace=True)
df.head()
# Out:
#    reviewid                 title            artist  \
# 0     22703             mezzanine    massive attack
# 1     22721          prelapsarian          krallice
# 2     22659  all of them naturals      uranium club
# 3     22659  all of them naturals      uranium club
# 4     22661           first songs  kleenex, liliput
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/22703-mezz...    9.3               0
# 1  http://pitchfork.com/reviews/albums/22721-prel...    7.9               0
# 2  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 3  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 4  http://pitchfork.com/reviews/albums/22661-firs...    9.0               1
#
#            author               author_type    pub_date  pub_weekday  pub_day  \
# 0     nate patrin               contributor  2017-01-08            6        8
# 1        zoe camp               contributor  2017-01-07            5        7
# 2  david glickman               contributor  2017-01-07            5        7
# 3  david glickman               contributor  2017-01-07            5        7
# 4      jenn pelly  associate reviews editor  2017-01-06            4        6
#
#    pub_month  pub_year    year       genre               label
# 0          1      2017  1998.0  electronic              virgin
# 1          1      2017  2016.0       metal           hathenter
# 2          1      2017  2016.0        rock        static shock
# 3          1      2017  2016.0        rock  fashionable idiots
# 4          1      2017  2016.0        rock     kill rock stars

# %%
df.dtypes
# Out:
# reviewid            int64
# title              object
# artist             object
# url                object
# score             float64
# best_new_music      int64
# author             object
# author_type        object
# pub_date           object
# pub_weekday         int64
# pub_day             int64
# pub_month           int64
# pub_year            int64
# year              float64
# genre              object
# label              object
# dtype: object

# %%
df['pub_date'] = pd.to_datetime(df['pub_date'])

# %%
df.dtypes
# Out:
# reviewid                   int64
# title                     object
# artist                    object
# url                       object
# score                    float64
# best_new_music             int64
# author                    object
# author_type               object
# pub_date          datetime64[ns]
# pub_weekday                int64
# pub_day                    int64
# pub_month                  int64
# pub_year                   int64
# year                     float64
# genre                     object
# label                     object
# dtype: object

# %%
df.head()
# Out:
#    reviewid                 title            artist  \
# 0     22703             mezzanine    massive attack
# 1     22721          prelapsarian          krallice
# 2     22659  all of them naturals      uranium club
# 3     22659  all of them naturals      uranium club
# 4     22661           first songs  kleenex, liliput
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/22703-mezz...    9.3               0
# 1  http://pitchfork.com/reviews/albums/22721-prel...    7.9               0
# 2  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 3  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 4  http://pitchfork.com/reviews/albums/22661-firs...    9.0               1
#
#            author               author_type   pub_date  pub_weekday  pub_day  \
# 0     nate patrin               contributor 2017-01-08            6        8
# 1        zoe camp               contributor 2017-01-07            5        7
# 2  david glickman               contributor 2017-01-07            5        7
# 3  david glickman               contributor 2017-01-07            5        7
# 4      jenn pelly  associate reviews editor 2017-01-06            4        6
#
#    pub_month  pub_year    year       genre               label
# 0          1      2017  1998.0  electronic              virgin
# 1          1      2017  2016.0       metal           hathenter
# 2          1      2017  2016.0        rock        static shock
# 3          1      2017  2016.0        rock  fashionable idiots
# 4          1      2017  2016.0        rock     kill rock stars

# %%
year_rev = pd.pivot_table(df, index='pub_year', values='score')
min=1999
max=2017
plt.plot(year_rev)
plt.ylim(0,10)
plt.xticks(np.arange(min, max+1, 1.0))
# Out:
# ([<matplotlib.axis.XTick at 0x13a9b678048>,
#   <matplotlib.axis.XTick at 0x13a95290e80>,
#   <matplotlib.axis.XTick at 0x13a952c4278>,
#   <matplotlib.axis.XTick at 0x13a9cbea080>,
#   <matplotlib.axis.XTick at 0x13a9cbeabe0>,
#   <matplotlib.axis.XTick at 0x13a9cbed780>,
#   <matplotlib.axis.XTick at 0x13a9cbf2320>,
#   <matplotlib.axis.XTick at 0x13a9cbf2e80>,
#   <matplotlib.axis.XTick at 0x13a9cbf8a20>,
#   <matplotlib.axis.XTick at 0x13a9cbfa5c0>,
#   <matplotlib.axis.XTick at 0x13a9cbff160>,
#   <matplotlib.axis.XTick at 0x13a9cbffcc0>,
#   <matplotlib.axis.XTick at 0x13a9cc04860>,
#   <matplotlib.axis.XTick at 0x13a9cc07400>,
#   <matplotlib.axis.XTick at 0x13a9cc07f60>,
#   <matplotlib.axis.XTick at 0x13a9cc0cb00>,
#   <matplotlib.axis.XTick at 0x13a9cc126a0>,
#   <matplotlib.axis.XTick at 0x13a9cc15240>,
#   <matplotlib.axis.XTick at 0x13a9cc15da0>],
#  <a list of 19 Text xticklabel objects>)

# %%
df.hist(column='score', bins=25)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000013A9CBFA940>]], dtype=object)

# %%
ten_albums = df.loc[df['score'] == 10,('title','artist')].drop_duplicates()
ten_albums.head()
# Out:
#                         title            artist
# 253                 metal box  public image ltd
# 264       blood on the tracks         bob dylan
# 456       another green world         brian eno
# 585  songs in the key of life     stevie wonder
# 681                in concert       nina simone

# %%
zero_albums = df.loc[df['score'] <= 1.0,('title','artist')].drop_duplicates()
print(len(zero_albums))
zero_albums.head()
# Out:
# 35
#                      title                       artist
# 5090                  ep-1                       pixies
# 7898       blue slide park                   mac miller
# 8074                  lulu          lou reed, metallica
# 12863  johnny cash remixed              various artists
# 12934   the effects of 333  black rebel motorcycle club

# %%
df1 = pd.pivot_table(df, index=['label'], values=['score'], aggfunc='count')
df1.columns = ['scores_count']
df2 = pd.pivot_table(df, index=['label'], values=['score'])
df2.columns = ['scores_mean']
label_info = pd.concat((df1, df2), axis=1)
label_info.head()
# Out:
#              scores_count  scores_mean
# label
#  deux                   1     5.800000
# !k7                    85     6.983529
# +1                      4     6.625000
# 00:02:59                1     7.400000
# 1-2-3-4 go!             2     6.750000

# %%
label_info = label_info.loc[label_info['scores_count'] > 19, :]
label_info_sort = label_info.sort_values(by='scores_mean', ascending=False)
label_info_sort = label_info_sort[0:20]
label_info_sort.head()
# Out:
#                        scores_count  scores_mean
# label
# hip-o select                     22     8.513636
# paradise of bachelors            23     7.995652
# light in the attic               88     7.982955
# what's your rupture?             26     7.957692
# tzadik                           42     7.940476

# %%
df.head()
# Out:
#    reviewid                 title            artist  \
# 0     22703             mezzanine    massive attack
# 1     22721          prelapsarian          krallice
# 2     22659  all of them naturals      uranium club
# 3     22659  all of them naturals      uranium club
# 4     22661           first songs  kleenex, liliput
#
#                                                  url  score  best_new_music  \
# 0  http://pitchfork.com/reviews/albums/22703-mezz...    9.3               0
# 1  http://pitchfork.com/reviews/albums/22721-prel...    7.9               0
# 2  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 3  http://pitchfork.com/reviews/albums/22659-all-...    7.3               0
# 4  http://pitchfork.com/reviews/albums/22661-firs...    9.0               1
#
#            author               author_type   pub_date  pub_weekday  pub_day  \
# 0     nate patrin               contributor 2017-01-08            6        8
# 1        zoe camp               contributor 2017-01-07            5        7
# 2  david glickman               contributor 2017-01-07            5        7
# 3  david glickman               contributor 2017-01-07            5        7
# 4      jenn pelly  associate reviews editor 2017-01-06            4        6
#
#    pub_month  pub_year    year       genre               label
# 0          1      2017  1998.0  electronic              virgin
# 1          1      2017  2016.0       metal           hathenter
# 2          1      2017  2016.0        rock        static shock
# 3          1      2017  2016.0        rock  fashionable idiots
# 4          1      2017  2016.0        rock     kill rock stars

# %%
df1 = pd.pivot_table(df, index=['artist'], values=['score'], aggfunc='count')
df1.columns = ['scores_count']
df2 = pd.pivot_table(df, index=['artist'], values=['score'])
df2.columns = ['scores_mean']
artist_info = pd.concat((df1, df2), axis=1)
artist_info.head()
# Out:
#               scores_count  scores_mean
# artist
# !!!                      6     6.933333
# !!!, out hud             4     6.000000
# +/-                      6     7.100000
# -ziq                     6     7.816667
# -ziq, kazumi             1     4.900000

# %%
artist_info = artist_info.loc[artist_info['scores_count'] > 3, :]
artist_info_sort = artist_info.sort_values(by='scores_mean', ascending=False)
artist_info_sort = artist_info_sort[0:20]
artist_info_sort
# Out:
#                           scores_count  scores_mean
# artist
# my bloody valentine                  6     9.700000
# the velvet underground              13     9.592308
# otis redding                         6     9.500000
# fleetwood mac                        7     9.457143
# disco inferno                        6     9.333333
# funkadelic                           6     9.266667
# pavement                             8     9.212500
# prince, the revolution               8     9.175000
# glenn branca                         6     9.133333
# kendrick lamar                       8     9.125000
# ride                                 8     9.100000
# the beatles                         35     9.077143
# this heat                            5     9.000000
# max tundra                           6     9.000000
# mission of burma                     9     8.933333
# the jesus and mary chain             6     8.900000
# caetano veloso                       6     8.866667
# sleater-kinney                       5     8.860000
# miles davis                         19     8.789474
# joanna newsom                        5     8.760000

# %%
artist_info = artist_info.loc[artist_info['scores_count'] > 3, :]
artist_info_sort = artist_info.sort_values(by='scores_mean')
artist_info_sort = artist_info_sort[0:20]
artist_info_sort
# Out:
#                                       scores_count  scores_mean
# artist
# chiddy bang                                      6     2.100000
# bravehearts                                      6     2.500000
# whirlwind heat                                   6     2.766667
# louis xiv                                        6     2.833333
# the bravery                                      6     3.133333
# har mar superstar                                6     3.233333
# ok go                                            6     3.400000
# ed harcourt                                      5     3.580000
# the dandy warhols                               10     3.620000
# the get up kids                                 12     3.666667
# joan of arc                                     12     3.683333
# morcheeba                                        9     3.800000
# stereophonics                                    8     3.925000
# the maccabees                                    6     4.066667
# gomez                                            6     4.083333
# the (international) noise conspiracy             6     4.216667
# tricky                                           8     4.287500
# n.e.r.d.                                        12     4.300000
# moby                                             8     4.387500
# the mars volta                                   9     4.400000
